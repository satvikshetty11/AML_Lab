# %%
import matplotlib.pyplot as plt

kashmir = [
    27.1, 26.3, 26.9, 28.9, 28.5, 27.2, 27.5, 27.5, 27.6, 28.6,
    27.6, 26.0, 25.5, 25.9, 26.7, 28.5, 28.8, 28.8, 27.0, 25.7,
    23.5, 19.1, 19.8, 20.5, 19.9, 22.7, 24.2
]

kanyakumari = [
    28.0, 28.5, 28.5, 28.5, 28.5, 29.0, 29.0, 28.5, 29.5, 29.5,
    29.0, 29.0, 28.0, 28.5, 29.0, 29.0, 27.5, 27.0, 27.0, 25.0,
    27.0, 26.5, 26.0, 26.0, 27.0, 26.0, 25.0
]

dates = range(1, len(kashmir) + 1)

plt.plot(dates, kashmir, label='Kashmir')
plt.plot(dates, kanyakumari, label='Kanyakumari')

plt.title('Average Daily Temperature in July 2026')
plt.xlabel('Date')
plt.ylabel('Average Temperature (°C)')
plt.legend()

plt.show()
